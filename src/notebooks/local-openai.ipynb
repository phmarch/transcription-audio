# %%
import subprocess


model = "facebook/opt-125m"

cmd = ["vllm", "serve", model, "--port", "8125"]

# subprocess.run(cmd)

# %%
import torch

print("torch:", torch.__version__)
print("cuda:", torch.version.cuda)
print("cuda available:", torch.cuda.is_available())
print("device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)
# Out:
# torch: 2.10.0+cu128
# cuda: 12.8
# cuda available: True
# device: NVIDIA GeForce RTX 3090

# %% [markdown]
# ```bash
# uv run vllm serve TinyLlama/TinyLlama-1.1B-Chat-v1.0 \
#   --port 8000 \
#   --served-model-name tiny
#
# ```

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://127.0.0.1:8000/v1",
    api_key="EMPTY",
)

r = client.chat.completions.create(
    model="tiny",
    messages=[{"role": "user", "content": "Litterally just repeat after me: <OK>"}],
    max_tokens=100,
)

print(r.choices[0].message.content)
# Out:
# Litterally, just repeat after me:
#
# Ole cay cay ew
# Et kalle kalle
# Ole cay cay et kalle kalle
#
# Litteraly, repeat after me:
#
# Ole cay cay et kalle kalle
# Et ufteminet bil
# Ole cay cay et ufteminet bil
#
# Litterally, repeat after me:
#
# Ole cay
